# %%
# Question 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
#Import the dataset Salary_Data.csv
data = pd.read_csv("D:\\workspace\\ucm\\ml\\assignment4\\Salary_Data.csv")
#first few rows of dataset
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#basic description of dataset
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
#Split the data and 1/3 of the data is reserved as test subset.
X = data.iloc[:, :-1].values
Y = data.iloc[:, 1].values

X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size=0.33, random_state=4)

# %%
#Training the model for linearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_Train, Y_Train)
# Out:
# LinearRegression()

# %%
# Predicting test result 
Y_Pred = lin_reg.predict(X_Test)
Y_Pred
# Out:
# array([ 63116.62489678,  92781.58020231, 123403.46954996,  71729.03127581,
#         89910.77807597, 110963.32700248,  75556.76744426, 125317.33763419,
#         82255.30573906,  35365.53767547])

# %%
# calculating meanSquare error
print(metrics.mean_squared_error(Y_Test,Y_Pred))
# Out:
# 35241306.15012057

# %%
#Visualize Train dataset
plt.scatter(X_Train, Y_Train, color = "green")
plt.plot(X_Train, lin_reg.predict(X_Train), color = "red")
plt.xlabel("experience")
plt.ylabel("salary")
plt.title("training data visualization")
plt.show()

# %%
#Visualize Test dataset
plt.scatter(X_Test, Y_Test, color = "blue")
plt.plot(X_Train, lin_reg.predict(X_Train), color = "red")
plt.title("testing data visualization")
plt.xlabel("experience")
plt.ylabel("salary")
plt.show()

# %%
# Question 2
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(style="white", color_codes=True)
import warnings
warnings.filterwarnings("ignore")

# %%
#Import the dataset K-Mean_Dataset.csv
data = pd.read_csv("D:\\workspace\\ucm\\ml\\assignment4\\K-Mean_Dataset.csv")
#first few rows of dataset
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
#checking for Null values
X = data.iloc[:, :-1].values
Y = data.iloc[:, 1].values 
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X,Y,test_size=0.2,random_state = 0)

data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# le = LabelEncoder() 
data['CUST_ID'] = le.fit_transform(data.CUST_ID.values) 
# filling null values with mean values
X_new= data.fillna(data.mean())
data.head()
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0        0    40.900749           0.818182      95.40              0.00
# 1        1  3202.467416           0.909091       0.00              0.00
# 2        2  2495.148862           1.000000     773.17            773.17
# 3        3  1666.670542           0.636364    1499.00           1499.00
# 4        4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
# Checking if null values are replaced
X_new.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
#elbow method to know the number of clusters
Inertia = [] 
for i in range(1,11): 
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=9,random_state=3) 
    kmeans.fit(X_new) 
    Inertia.append(kmeans.inertia_)

plt.plot(range(1,11),Inertia) 
plt.title('the elbow method') 
plt.xlabel('Number of Clusters') 
plt.ylabel('Inertia') 
plt.show()

# %%
#Calculate the silhouette score for the above clustering
n_clusters = 2
kmeans = KMeans(n_clusters = n_clusters) 
kmeans.fit(X_new)

# predict the cluster for each data point
y_kmeans = kmeans.predict(X_new) 
score = metrics.silhouette_score(X_new, y_kmeans) 
print(score)
# Out:
# 0.4272072267584384

# %%
# Question 3
#feature scaling 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import metrics 
from sklearn.cluster import KMeans 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder, StandardScaler

#Import the dataset K-Mean_Dataset.csv
data = pd.read_csv("D:\\workspace\\ucm\\ml\\assignment4\\K-Mean_Dataset.csv")
#first few rows of dataset
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
#feature scaling 

X = data.iloc[:, :-1].values
Y = data.iloc[:, 1].values 
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X,Y,test_size=0.2,random_state = 0)

data.isnull().sum()

le = LabelEncoder() 
data['CUST_ID'] = le.fit_transform(data.CUST_ID.values) 
X_new= data.fillna(data.mean())

data.head()
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0        0    40.900749           0.818182      95.40              0.00
# 1        1  3202.467416           0.909091       0.00              0.00
# 2        2  2495.148862           1.000000     773.17            773.17
# 3        3  1666.670542           0.636364    1499.00           1499.00
# 4        4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
Inertia = [] 
for i in range(1,11): 
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=9,random_state=3) 
    kmeans.fit(X_new)
Inertia.append(kmeans.inertia_)
scaler = StandardScaler()
scaler.fit(X_new)
X_scaled_array = scaler.transform(X_new)
X_scaled = pd.DataFrame(X_scaled_array, columns = X_new.columns)

#After feature scaling calculating silhouette score
nclusters = 2 
km = KMeans(n_clusters=nclusters)
km.fit(X_scaled)

y_cluster_kmeans = km.predict(X_scaled)
score = metrics.silhouette_score(X_scaled, y_cluster_kmeans)
print(score)
# Out:
# 0.1919748976345269

# %%
#the answer is no. after feature scaling also it is not improving the Silhouette score.

#After doing feature scaling dataset becomes more normalize so silhouette score should increased but it actually decreased
#from 0.427 to 0.192. The range of silhoutte score is from -1 to 1. 1 means data in one cluster is very similar and different
#from data of other clusters.
